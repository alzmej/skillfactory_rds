# %%
Задача этого проекта - отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет 
на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.

# %%
import pandas as pd
import numpy as na
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колонок

stud = pd.read_csv('stud_math.csv')

# %%
display(stud.head(50))
stud.info()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1      GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6      GP   M   16     NaN     LE3       T   2.0   2.0     other     other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9      GP   M   15       U     NaN     NaN   3.0   4.0     other     other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# ...

# %%
stud = stud.rename(columns={'studytime, granular': 'granular'})

# %%
stud.address = stud.address.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.famsize = stud.famsize.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.Pstatus = stud.Pstatus.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.Mjob = stud.Mjob.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.Fjob = stud.Fjob.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.reason = stud.reason.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.guardian = stud.guardian.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.schoolsup = stud.schoolsup.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.famsup = stud.famsup.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.paid = stud.paid.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.activities = stud.activities.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.nursery = stud.nursery.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.higher = stud.higher.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.internet = stud.internet.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)
stud.romantic = stud.romantic.astype(str).apply(
    lambda x: None if x.strip() == 'NaN' else x)

# %%
display(stud.head(50))
stud.info()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     nan       A   4.0   4.0   at_home   teacher
# 1      GP   F   17       U     GT3     nan   1.0   1.0   at_home     other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health       nan
# 4      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6      GP   M   16     nan     LE3       T   2.0   2.0     other     other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9      GP   M   15       U     nan     nan   3.0   4.0     other     other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# ...

# %%
stud.age.hist()
stud.age.describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
stud.Medu.hist()
stud.Medu.describe()
# Out:
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64

# %%
stud.Fedu.hist()
stud.Fedu.describe()
# Out:
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: Fedu, dtype: float64

# %%
stud.Fedu = stud.Fedu.apply(lambda x: 4.0 if x == 40.0 else x)
stud.Fedu.hist()
stud.Fedu.describe()
# Out:
# count    371.000000
# mean       2.517520
# std        1.088808
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64

# %%
stud.traveltime.hist()
stud.traveltime.describe()
# Out:
# count    367.000000
# mean       1.438692
# std        0.694181
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64

# %%
stud.studytime.hist()
stud.studytime.describe()
# Out:
# count    388.000000
# mean       2.038660
# std        0.842078
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: studytime, dtype: float64

# %%
stud.failures.hist()
stud.failures.describe()
# Out:
# count    373.000000
# mean       0.337802
# std        0.743135
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: failures, dtype: float64

# %%
stud.granular.hist()
stud.granular.describe()
# Out:
# count    388.000000
# mean      -6.115979
# std        2.526235
# min      -12.000000
# 25%       -6.000000
# 50%       -6.000000
# 75%       -3.000000
# max       -3.000000
# Name: granular, dtype: float64

# %%
stud.famrel.hist()
stud.famrel.describe()
# Out:
# count    368.000000
# mean       3.937500
# std        0.927277
# min       -1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %%
stud.famrel = stud.famrel.apply(lambda x: 1.0 if x == -1.0 else x)
stud.famrel.hist()
stud.famrel.describe()
# Out:
# count    368.000000
# mean       3.942935
# std        0.903824
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %%
stud.freetime.hist()
stud.freetime.describe()
# Out:
# count    384.000000
# mean       3.231771
# std        0.993940
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64

# %%
stud.goout.hist()
stud.goout.describe()
# Out:
# count    387.000000
# mean       3.105943
# std        1.115896
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: goout, dtype: float64

# %%
stud.health.hist()
stud.health.describe()
# Out:
# count    380.000000
# mean       3.531579
# std        1.396019
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: health, dtype: float64

# %%
stud.absences.hist()
stud.absences.describe()
# Out:
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %%
# определяем границы выбросов
IQR = stud.absences.quantile(0.75) - stud.absences.quantile(0.25)
perc25 = stud.absences.quantile(0.25)
perc75 = stud.absences.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75),
      "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))

stud.absences.loc[stud.absences.between(
    perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins=10, range=(0, 10), label='IQR')

plt.legend()
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %%
# отбираем данные по границам выбросов
stud = stud.loc[stud.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)]
stud.absences.hist()
stud.absences.describe()
# Out:
# count    366.000000
# mean       4.603825
# std        4.965512
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        7.000000
# max       20.000000
# Name: absences, dtype: float64

# %%
stud.score.hist()
stud.score.describe()
# Out:
# count    361.000000
# mean      51.994460
# std       22.956117
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
# определяем границы выбросов
IQR = stud.score.quantile(0.75) - stud.score.quantile(0.25)
perc25 = stud.score.quantile(0.25)
perc75 = stud.score.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75),
      "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))

stud.score.loc[stud.score.between(
    perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins=10, range=(0, 10), label='IQR')

plt.legend()
# Out:
# 25-й перцентиль: 40.0, 75-й перцентиль: 70.0, IQR: 30.0,  Границы выбросов: [-5.0, 115.0].

# %%
# таким образом выбросов тут нет

# %%
display(pd.DataFrame(stud.school.value_counts()))
# Out:
#     school
# GP     322
# MS      44

# %%
display(pd.DataFrame(stud.sex.value_counts()))
# Out:
#    sex
# F  191
# M  175

# %%
display(pd.DataFrame(stud.address.value_counts()))
# Out:
#      address
# U        273
# R         78
# nan       15

# %%
display(pd.DataFrame(stud.famsize.value_counts()))
# Out:
#      famsize
# GT3      245
# LE3       99
# nan       22

# %%
display(pd.DataFrame(stud.Pstatus.value_counts()))
# Out:
#      Pstatus
# T        296
# nan       38
# A         32

# %%
display(pd.DataFrame(stud.Mjob.value_counts()))
# Out:
#           Mjob
# other      123
# services    88
# at_home     55
# teacher     52
# health      32
# nan         16

# %%
display(pd.DataFrame(stud.Fjob.value_counts()))
# Out:
#           Fjob
# other      185
# services    92
# nan         34
# teacher     25
# at_home     16
# health      14

# %%
display(pd.DataFrame(stud.reason.value_counts()))
# Out:
#             reason
# course         129
# reputation      94
# home            94
# other           32
# nan             17

# %%
display(pd.DataFrame(stud.guardian.value_counts()))
# Out:
#         guardian
# mother       229
# father        83
# nan           30
# other         24

# %%
display(pd.DataFrame(stud.schoolsup.value_counts()))
# Out:
#      schoolsup
# no         310
# yes         47
# nan          9

# %%
display(pd.DataFrame(stud.famsup.value_counts()))
# Out:
#      famsup
# yes     204
# no      127
# nan      35

# %%
display(pd.DataFrame(stud.paid.value_counts()))
# Out:
#      paid
# no    189
# yes   139
# nan    38

# %%
display(pd.DataFrame(stud.activities.value_counts()))
# Out:
#      activities
# yes         184
# no          168
# nan          14

# %%
display(pd.DataFrame(stud.nursery.value_counts()))
# Out:
#      nursery
# yes      277
# no        73
# nan       16

# %%
display(pd.DataFrame(stud.higher.value_counts()))
# Out:
#      higher
# yes     332
# nan      18
# no       16

# %%
display(pd.DataFrame(stud.internet.value_counts()))
# Out:
#      internet
# yes       279
# no         55
# nan        32

# %%
display(pd.DataFrame(stud.romantic.value_counts()))
# Out:
#      romantic
# no        225
# yes       111
# nan        30

# %%
sns.pairplot(stud, kind='reg')

# %%
stud.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.182463 -0.185368    0.085659   0.003035  0.195400
# Medu       -0.182463  1.000000  0.629212   -0.197009   0.085532 -0.249754
# Fedu       -0.185368  0.629212  1.000000   -0.145846   0.005116 -0.289421
# traveltime  0.085659 -0.197009 -0.145846    1.000000  -0.093825  0.085026
# studytime   0.003035  0.085532  0.005116   -0.093825   1.000000 -0.174802
# failures    0.195400 -0.249754 -0.289421    0.085026  -0.174802  1.000000
# granular   -0.003035 -0.085532 -0.005116    0.093825  -1.000000  0.174802
# famrel      0.063204 -0.023323 -0.029874   -0.025343   0.029926  0.009730
# freetime    0.058193  0.027861 -0.021205   -0.008602  -0.136510  0.098642
# goout       0.135466  0.049094  0.029427    0.031481  -0.034197  0.085448
# health     -0.067958 -0.052316  0.023932   -0.006809  -0.090552  0.084991
# absences    0.151493  0.065712 -0.021811   -0.047995  -0.078099  0.081801
# ...

# %%
#слабая корреляция с Medu, Fedu, studytime 
#слабая отрицательная корреляция с age, failures, goout

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize=(14, 4))
    sns.boxplot(x=column, y='score',
                data=stud.loc[stud.loc[:, column].isin(
                    stud.loc[:, column].value_counts().index[:10])],
                ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()


for col in ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_boxplot(col)

# %%
def get_stat_dif(column):
    cols = stud.loc[:, column].value_counts().index[:5]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(stud.loc[stud.loc[:, column] == comb[0], 'score'],
                     stud.loc[stud.loc[:, column] == comb[1], 'score']).pvalue \
                <= 0.05/len(combinations_all):  # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break


for col in ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки Mjob
# Найдены статистически значимые различия для колонки higher

# %%
stud_for_model = stud.loc[:, ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason',
                              'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']]
stud_for_model.head()
# Out:
#   school sex address famsize Pstatus     Mjob     Fjob  reason guardian  \
# 0     GP   F       U     nan       A  at_home  teacher  course   mother
# 1     GP   F       U     GT3     nan  at_home    other  course   father
# 2     GP   F       U     LE3       T  at_home    other   other   mother
# 3     GP   F       U     GT3       T   health      nan    home   mother
# 4     GP   F       U     GT3       T    other    other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes      nan       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  nan         no     yes    yes      yes      nan
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
# таким образом для модели могут быть использованы колонки 
# Medu, Fedu, studytime, age, failures, goout, Mjob, higher

# %%
Итак, в результате EDA для анализа влияния условий жизни учащихся в возрасте от 15 до 22 лет 
на их успеваемость по математике, были получены следующие выводы:

1. В данных достаточно мало пустых значений, хуже всего заполнен столбец Pstatus на 88 %, в то же время 
полностью заполнено только 3 из 30 столбцов.
2. Выбросы найдены только в столбце absences и famrel, что позволяет сделать вывод о том, что 
данные достаточно чистые.
3. Положительная корреляция параметра Medu и Fedu может говорить о том, что образование родителей 
положительно влияет на успеваемость, положительна корреляция значения studytime о полезностии 
для успеваемости дополнительно времени учёбы, статистическая значимость Mjob, higher о положительном влияни 
места работы матери и мотивирующего желания получить высшее образование.
Отрицательная корреляция failures и goout может говорить о недостаточном проявленом усердии.
4. Самые важные параметры, которые предлагается использовать в дальнейшем для построения модели,
это Medu, Fedu, studytime, Mjob, higher, failures, goout.
